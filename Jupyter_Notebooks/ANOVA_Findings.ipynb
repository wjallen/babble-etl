# %% [markdown]
# Single Variable Analysis
# ------------------------
#
# ### Variables that Significantly Affect the Dependent Variable (**Babbles**)
#
# We **reject the null hypothesis** for the following variables, indicating they significantly affect the dependent variable:
#
# 1. **Days Prior to Fledging**
#
#     -   *p-value*: 1.49 × 10⁻¹⁹
#     -   Interpretation: Days prior to fledging significantly affects the dependent variable.
# 2.  **Age on Bout Day**
#
#     -   *p-value*: 2.03 × 10⁻¹⁷
#     -   Interpretation: Age on bout day significantly affects the dependent variable.
# 3.  **Period**
#
#     -   *p-value*: 5.56 × 10⁻¹⁶
#     -   Interpretation: Period significantly affects the dependent variable.
# 4.  **Audition Work**
#
#     -   *p-value*: 1.13 × 10⁻⁷
#     -   Interpretation: Audition work significantly affects the dependent variable.
# 5.  **Nest ID**
#
#     -   *p-value*: 1.30 × 10⁻¹⁰
#     -   Interpretation: Nest ID significantly affects the dependent variable.
# 6.  **Date on Vocalization / Date on Vocalization 2**
#
#     -   *p-value*: 1.40 × 10⁻⁵
#     -   Interpretation: Date on vocalization and Date on vocalization 2 significantly affects the dependent variable.
# 7.  **Hatch Date**
#
#     -   *p-value*: 3.96 × 10⁻⁷
#     -   Interpretation: Hatch date significantly affects the dependent variable.
# 8.  **Fledge Date**
#
#     -   *p-value*: 5.05 × 10⁻⁷
#     -   Interpretation: Fledge date significantly affects the dependent variable.
# 9.  **Fledge Age**
#
#     -   *p-value*: 0.0226
#     -   Interpretation: Fledge age significantly affects the dependent variable.
#
# * * * * *
#
# ### Variables that Do Not Significantly Affect the Dependent Variable (**Babbles**)
#
# We **accept the null hypothesis** for the following variables, indicating they do not significantly affect the dependent variable:
#
# 1.  **Nestling ID**
#
#     -   *p-value*: 0.2059
#     -   Interpretation: Nestling ID does not significantly affect the dependent variable.
# 2.  **Hatchno**
#
#     -   *p-value*: 0.0643
#     -   Interpretation: Hatchno does not significantly affect the dependent variable.
# 3.  **Hatseq**
#
#     -   *p-value*: 0.1140
#     -   Interpretation: Hatseq does not significantly affect the dependent variable.
# 4.  **Sex**
#
#     -   *p-value*: 0.1140
#     -   Interpretation: Sex does not significantly affect the dependent variable.
# 5.  **Nestling**
#
#     -   *p-value*: 0.4130
#     -   Interpretation: Nestling does not significantly affect the dependent variable.
# 6.  **Treatment**
#
#     -   *p-value*: 0.4375
#     -   Interpretation: Treatment does not significantly affect the dependent variable.
# 7.  **Number of Eggs Hatched from Nest**
#
#     -   *p-value*: 0.4375
#     -   Interpretation: Number of eggs hatched from nest does not significantly affect the dependent variable.
# 8.  **Number of Birds Fledged from Nest**
#
#     -   *p-value*: 0.1038
#     -   Interpretation: Number of birds fledged from nest does not significantly affect the dependent variable.
# 9.  **Bout Number**
#
#     -   *p-value*: 0.3883
#     -   Interpretation: Bout number does not significantly affect the dependent variable.
